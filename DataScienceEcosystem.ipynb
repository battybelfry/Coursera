# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Author
# Jessica Hope Goble

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystems are summarized.

# %% [markdown]
# **Objectives:**
# - List popular Data Science languages
# - List common Data Science libraries
# - Make a table of common Data Science tools
# - Provide examples of evaluating arthmetic expression

# %% [markdown]
# Some of the popular languages used by Data Scientists include:
# 1. Python
# 2. R
# 3. Julia
# 4. SQL
# 5. Matlab
# 6. Java

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. ggplot2
# 2. caret
# 3. dplyr
# 4. NumPy
# 5. Pandas
# 6. Matplotlib
# 7. Seaborn
# 8. Scikit-learn
# 9. Keras
# 10. TensorFlow
# 11. PyTorch

# %% [markdown]
# | Data Science Tools     |
# |------------------------|
# | Jupyter Notebook       |
# | RStudio                |
# | Microsoft Visual Studio|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expression examples

# %%
# This is a simple arithmetic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes into hours by diving by 60
200/60
# Out:
# 3.3333333333333335
